# %% [markdown]
# Now we are ready to get started exploring kinematics! Lets begin with some mathematical basics. We will refresh some of our linear algebra skills

# %%
import numpy as np

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
vector = np.array([3,4])
magnitude = np.linalg.norm(vector)

# %%
magnitude
# Out:
# 5.0
